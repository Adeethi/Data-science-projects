# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## a. Data Preparation and Understanding
#
# ### 1. Reading the data

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv("Cardiotocographic.csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# ### 2. Contextual Overview
# Fetal cardiotocography (CTG)  is a common method used to monitor fetal well-being during pregnancy and labor by assessing the fetal heart rate (FHR) and uterine activity.
#
# #### Column-Specific Domain Knowledge
# <b>1. LB (Baseline Fetal Heart Rate - FHR)</b><br>
# Represents the average fetal heart rate, usually measured in beats per minute (BPM).
# Normal baseline ranges are typically between 110-160 BPM. Abnormal values may indicate distress or other complications.
#
# <b>2. AC (Accelerations)</b><br>
# Accelerations are temporary increases in FHR and are considered a positive sign of fetal well-being.
# They are often associated with fetal movement and suggest good oxygenation and a healthy autonomic nervous system.
#
# <b>3. FM (Fetal Movements)</b><br>
# Indicates the number or intensity of fetal movements detected.
# Active fetal movement is a reassuring sign of well-being, while reduced movements may warrant further investigation.
#
# <b>4. UC (Uterine Contractions)</b><br>
# Refers to the frequency and intensity of uterine contractions.
# Contractions can affect the FHR, and their interaction is crucial for assessing fetal well-being, especially during labor.
#
# <b>5. DL (Decelerations Late)</b><br>
# Late decelerations occur after the peak of a contraction and can indicate uteroplacental insufficiency (reduced blood flow/oxygen to the fetus).
# They are a potential sign of fetal distress and need monitoring.
#
# <b>6. DS (Decelerations Short)</b><br>
# Short decelerations are brief dips in FHR that may not be concerning unless frequent or associated with other abnormal patterns.
#
# <b>7. DP (Decelerations Prolonged)</b><br>
# Prolonged decelerations are sustained drops in FHR that may indicate more severe fetal distress, such as cord compression or hypoxia.
#
# <b>8. ASTV (Abnormal Short Term Variability)</b><br>
# Refers to the percentage of time the short-term variability in FHR (beat-to-beat changes) is abnormal.
# Reduced variability is often a concerning sign and may indicate compromised fetal health.
#
# <b>9. MSTV (Mean Short Term Variability)</b><br>
# Measures the average beat-to-beat variability in FHR.
# Normal values typically range between 5-25 milliseconds. Variability outside this range may reflect fetal distress.
#
# <b>10. ALTV (Abnormal Long Term Variability)</b><br>
# Indicates the percentage of time the long-term variability in FHR (cyclic changes over minutes) is abnormal.
# Abnormal patterns may suggest issues with fetal oxygenation or autonomic regulation.
#
# <b>11. MLTV (Mean Long Term Variability)</b><br>
# Refers to the average magnitude of cyclic changes in FHR over time.
# Healthy patterns show a balance of variability, while abnormal values may warrant further investigation.
#
# <b>Width</b><br>
# For now it is unsure what this column represents. We will eventually figure out through analysis.
#
# <b>Tendency</b><br>
# For now it is unsure what this column represents. We will eventually figure out through analysis.
#
# <b>NSP (Normal, Suspect, Pathologic)</b><br>
# Used as the primary outcome to assess whether the fetus is healthy or potentially at risk.

# %% [markdown]
# ##### Let's get a high level overview of the data and structure
#
# ### 3. Structure of Data

# %%
df.shape
# Out:
# (2126, 14)

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %% [markdown]
# We have all numeric columns with float values. We can also see some null values. The column names doesn't require any changes. The abbreviation is easy when doing column specific analysis

# %% [markdown]
# We will check if there is any presence of two or more columns with same data

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %% [markdown]
# The above table kind of gives an idea of the structure of data.

# %%
df.nunique()
# Out:
# LB           153
# AC          1067
# FM           776
# UC          1364
# DL           822
# DS           114
# DP           264
# ASTV         183
# MSTV         165
# ALTV         195
# MLTV         351
# Width        261
# Tendency     111
# NSP          111
# dtype: int64

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %% [markdown]
# The different kind of unique values in the data table suggests that there is no two or more columns with same information. Also, above table kind of gives an idea of the structure of the data
#
# ### 3. Initial Statistical summary
#
# Now as we have our statistical summary table above, we will highlight some of the key findings in the table:
#
# 1. The mean and median (50th percentile) for LB (Baseline Heart Rate) are close (133.34 vs. 133), indicating a roughly symmetric distribution.
# 2. Several features exhibit large differences between their minimum and maximum values, such as LB, ASTV, and MLTV, indicating potential outliers.
# 3. The minimum values in the table AC(Acceleration), FM(Fetal Movement),UC(Uterine Contractions), MLTV,ALTV are negative, which may not be physiologically meaningful, indicating potential data entry errors or measurement issues.
# 4. The variable NSP ranges from -1.02 to 5, with a mean of 1.30. This suggests that the dataset might contain mislabeled or anomalous cases, as NSP values are typically expected to represent discrete or categorical value.
# 5. The standard deviation is high for ASTV (18.85) and ALTV (21.29), suggesting high variability. This might indicate that these features capture significant differences in fetal behavior.
# 6. Tendency have values between -3 and 3 and mean of 0, possibly indication of standardized values
#
# We will keep this points in mind while doing our data cleaning.

# %% [markdown]
# ### 4. Data Cleaning
#
# Now, let's check if our dataset has any duplicates.

# %%
df[df.duplicated(keep = False)]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1113  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1457  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1113   39.0       0.0  1.0
# 1115   39.0       0.0  1.0
# 1457   35.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %% [markdown]
# We do have <b>two rows that are duplicate</b>(above table shows the matching rows as well, just to double check). Let us delete them.

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (2124, 14)

# %% [markdown]
# We have 2124 rows now.
#
# Let us check for null values in the dataset

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df[df['LB'].isnull()]
# Out:
#       LB        AC        FM        UC        DL  DS  DP       ASTV      MSTV  \
# 50   NaN       NaN  0.000000  0.008086  0.000000 NaN NaN  29.000000  1.300000
# 116  NaN  0.038567  0.000000  0.006993  0.002331 NaN NaN  26.000000  4.300000
# 126  NaN       NaN  0.000000  0.004380  0.000000 NaN NaN  69.000000  0.300000
# 201  NaN       NaN  0.016393  0.000000  0.000000 NaN NaN  56.000000  0.500000
# 566  NaN       NaN  0.000000  0.004115  0.005487 NaN NaN  43.000000  2.500000
# 574  NaN       NaN  0.000000  0.002611  0.002611 NaN NaN  34.000000  4.900000
# 603  NaN       NaN  0.006519  0.001304  0.001304 NaN NaN  73.000000  0.700000
# 935  NaN       NaN  0.000000  0.005495  0.001374 NaN NaN  30.000000  1.251793
# 936  NaN       NaN  0.000000  0.007802  0.000000 NaN NaN  33.000000  1.000000
# 1013 NaN       NaN  0.000000  0.003861  0.000000 NaN NaN  34.000000  1.000000
# 1205 NaN       NaN -0.000129  0.006424  0.000000 NaN NaN  63.000000  0.500000
# ...

# %% [markdown]
# We can see that there are same amount of null values in the columns that have null values - LB, AC, DS, DP, MLTV, Width, Tendency, NSP. And also, the missing values occur in the same rows across multiple columns( collective nulls). <b>We will go forward with deleting this rows, because:</b>
#
# 1. That many missing rows won't provide any meaningfull information about the whole data
# 2. Number of collective null rows is neglible compared to the whole dataset. There are 21 collective null rows(8 out of 14 column information are null) out of 2126 rows which is just 1% of data.
# 3. NSP column which seems to be a variable of interest is also null
# 4. Deleting these rows won't affect the rest of the data information.
#
# We will also cross check the statistical summary with between non null and dataframe with nulls to check if had any major effect.

# %%
cleaner_fetal = df.dropna()
cleaner_fetal.shape
# Out:
# (2103, 14)

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2103.000000  2104.000000  2124.000000  2124.000000  2124.000000
# mean    133.342023     0.003220     0.009904     0.004394     0.001897
# std      11.268266     0.004392     0.067571     0.003340     0.003344
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001858     0.000000
# 50%     133.000000     0.001634     0.000000     0.004486     0.000000
# 75%     140.000000     0.005650     0.002568     0.006536     0.003292
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2103.000000  2103.000000  2124.000000  2124.000000  2124.000000
# mean      0.000003     0.000175    47.012459     1.364345    10.295650
# std       0.000142     0.000840    18.812403     1.174084    21.212676
# ...

# %%
cleaner_fetal.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2103.000000  2103.000000  2103.000000  2103.000000  2103.000000
# mean    133.342023     0.003203     0.009973     0.004391     0.001894
# std      11.268266     0.004325     0.067902     0.003350     0.003349
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001838     0.000000
# 50%     133.000000     0.001631     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002559     0.006543     0.003295
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2103.000000  2103.000000  2103.000000  2103.000000  2103.000000
# mean      0.000003     0.000175    47.013569     1.360968    10.363493
# std       0.000142     0.000840    18.846186     1.173620    21.289827
# ...

# %% [markdown]
# We can safely conclude that deletion did not have any major effect. We know this because mean, IQR and standard deviation did not have any change with Alternatively, a histogram plot with also help to visualize this, but we won't do it for this usecase.

# %% [markdown]
# Earlier, in statistical summary we mentioned that AC, UC, FM and other veriability measures that have the possibility of error in data recording. 25th percentile of most of this records are 0 as well. So we are going to change those negative values to 0.
#
# <b>Note: The emphasis here is on the values being negative rather than capping on the lower limit.</b>

# %%
# List of columns to apply the transformation
columns_to_adjust = ["AC", "FM","UC","ASTV","MSTV","ALTV","MLTV"]

# Update values less than the 0 values
for col in columns_to_adjust:
    cleaner_fetal[col] = cleaner_fetal[col].apply(lambda x: max(x, 0))  # Replace values
cleaner_fetal.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2103.000000  2103.000000  2103.000000  2103.000000  2103.000000
# mean    133.342023     0.003241     0.011368     0.004419     0.001894
# std      11.268266     0.004214     0.062621     0.003247     0.003349
# min      51.842487     0.000000     0.000000     0.000000    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001838     0.000000
# 50%     133.000000     0.001631     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002559     0.006543     0.003295
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2103.000000  2103.000000  2103.000000  2103.000000  2103.000000
# mean      0.000003     0.000175    47.163355     1.370384    10.499515
# std       0.000142     0.000840    18.210563     1.135556    20.942663
# ...

# %% [markdown]
# Now let's check for outliers as there are many values far from the mean. We will just plot boxplot for every feature in the same plot to get a high level idea
# ### 4. Outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Melt the DataFrame for Seaborn
df_melted = cleaner_fetal.melt(var_name="Feature", value_name="Value")

# Plot boxplot
plt.figure(figsize=(20, 15))
sns.boxplot(x="Feature", y="Value", data=df_melted)
plt.title("Boxplot for All Features")
plt.xlabel("Features")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# The box plot above does detect outliers, but there are some columns for which we cannot visualize the outliers properly. It is because some columns has values within wide range and some are neglible. <b>To visualize better, we will scale the data using standard scaler and visualize to get a proper view.</b>

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
c =scaler.fit_transform(cleaner_fetal)
scaled_fetal = pd.DataFrame(c, columns = cleaner_fetal.columns)

# Melt the DataFrame for Seaborn
df_melted = scaled_fetal.melt(var_name="Feature", value_name="Value")

# Plot boxplot
plt.figure(figsize=(20, 15))
sns.boxplot(x="Feature", y="Value", data=df_melted)
plt.title("Boxplot for All Features")
plt.xlabel("Features")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# The above box plot confirms outliers in every column. We will also take a look at the histogram, before we decide on what to do with the outliers.

# %%
# Adjust the figure size to fit all plots without scrolling
plt.figure(figsize=(12, 4 * 7))

# Plot histograms with KDE
for i, column in enumerate(cleaner_fetal.columns, 1):  # Start index from 1 for subplot numbering
    plt.subplot(7, 2, i)
    sns.histplot(cleaner_fetal[column], kde=True, bins=20, color='cornflowerblue', alpha=0.7)
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Density')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# From the histogram plots above, it is evident that none of the columns in the data table exhibit a symmetric distribution. The histograms display characteristics such as skewness, multimodality (multiple peaks), or heavy tails. Biological data is often "not normally distributed," and the graphs indicate that our dataset aligns with this observation.
#
#
# At this point in the analysis, we have decided not to remove any outliers. This decision is based on several considerations:
#
# <b>Expected Skewness and Outliers:</b> The skewness and presence of outliers are characteristic of cardiotocographic data, so their existence aligns with the nature of the dataset. Removing or altering them prematurely may distort the underlying trends and potentially erase meaningful information.
#
# <b>Impact of Imputation or Capping:</b> Since there are numerous outliers, using methods such as imputation or capping could significantly alter the dataset, potentially leading to a loss of important insights or misrepresentation of the data's true behavior.
#
# <b>Uncertainty of Outlier Origin:</b> At this stage, without clarity on their origin of the data, removing or modifying these points would be speculative and potentially harmful to the integrity of the analysis.
#
# <b>Extreme Cases:</b> The extreme data points may correspond to critical cases such as fetal distress, making them natural outliers. These cases could provide important insights, so rather than removing them, the columns with such extreme data points can be flagged for separate analysis to better understand their implications.
#
# And lastly, we need to learn more about the patterns in the data. We can decide to remove them later after initial analysis and additional input from domain experts.

# %% [markdown]
# <b>For NSP, Let's create a separate categorical column as it is expected to be categorical column. It will be helpful in analysis later. And do the same about the Tendency column, too</b>

# %%
# Define bins and labels
bins = [0, 1.5, 2.5, 3.5]  # Adjust these based on your data
labels = ['Class 1', 'Class 2', 'Class 3']

# Use pd.cut to categorize
cleaner_fetal['NSP_cat'] = pd.cut(cleaner_fetal['NSP'], bins=bins, labels=labels, right=False)

# Verify the changes
cleaner_fetal.head(10)
# Out:
#            LB        AC   FM        UC        DL   DS        DP  ASTV  MSTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.000000  73.0   0.5
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.000000  17.0   2.1
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.000000  16.0   2.1
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.000000  16.0   2.4
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.000000  16.0   2.4
# 5  134.000000  0.001116  0.0  0.010493  0.009444  0.0  0.002099  26.0   5.9
# 6  134.000000  0.001403  0.0  0.012623  0.008415  0.0  0.002805  29.0   6.3
# 7  122.000000  0.000000  0.0  0.000000  0.000000  0.0  0.000000  83.0   0.5
# 8  122.000000  0.038567  0.0  0.001517  0.000000  0.0  0.000000  84.0   0.5
# 9  122.000000  0.000000  0.0  0.002967  0.000000  0.0  0.000000  86.0   0.3
#
#    ALTV  MLTV       Width  Tendency       NSP  NSP_cat
# 0  43.0   2.4   64.000000  0.999926  2.000000  Class 2
# ...

# %%
#replace null valuess with mode value
cleaner_fetal.loc[cleaner_fetal['NSP_cat'].isnull(), 'NSP_cat'] = 'Class 1'

cleaner_fetal.head(10)
# Out:
#            LB        AC   FM        UC        DL   DS        DP  ASTV  MSTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.000000  73.0   0.5
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.000000  17.0   2.1
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.000000  16.0   2.1
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.000000  16.0   2.4
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.000000  16.0   2.4
# 5  134.000000  0.001116  0.0  0.010493  0.009444  0.0  0.002099  26.0   5.9
# 6  134.000000  0.001403  0.0  0.012623  0.008415  0.0  0.002805  29.0   6.3
# 7  122.000000  0.000000  0.0  0.000000  0.000000  0.0  0.000000  83.0   0.5
# 8  122.000000  0.038567  0.0  0.001517  0.000000  0.0  0.000000  84.0   0.5
# 9  122.000000  0.000000  0.0  0.002967  0.000000  0.0  0.000000  86.0   0.3
#
#    ALTV  MLTV       Width  Tendency       NSP  NSP_cat
# 0  43.0   2.4   64.000000  0.999926  2.000000  Class 2
# ...

# %%
# Categorize Tendency into 'Negative', 'Neutral', and 'Positive'
def categorize_tendency(value):
    if value < 0:
        return 'Negative'
    elif value == 0:
        return 'Neutral'
    else:
        return 'Positive'

cleaner_fetal['Tendency_Category'] = cleaner_fetal['Tendency'].apply(categorize_tendency)
cleaner_fetal.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP  NSP_cat Tendency_Category
# 0   2.4   64.0  0.999926  2.0  Class 2          Positive
# 1  10.4  130.0  0.000000  1.0  Class 1           Neutral
# 2  13.4  130.0  0.000000  1.0  Class 1           Neutral
# 3  23.0  117.0  1.000000  1.0  Class 1          Positive
# 4  19.9  117.0  1.000000  1.0  Class 1          Positive

# %% [markdown]
# ## b. Data visualization, pattern recognition and Insights
#
# First, Let us check the correlation between all the variables by checking their correlation coefficient, plotting a heatmap and also additionally with scatterplot

# %%
# Assuming 'data' is your DataFrame
plt.figure(figsize=(12, 8))  # Set the figure size
correlation_matrix = cleaner_fetal.corr()  # Compute the correlation matrix
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True, linewidths=0.5)

# Add a title for better interpretation
plt.title("Correlation Heatmap", fontsize=16)
plt.show()

# %%
sns.pairplot(data=cleaner_fetal, palette='Set2')

# Show the plot
plt.show()

# %% [markdown]
# It seems like we do not have much correlation between the features as most of them are between -0.20 and 0.20. There some with 40% positive correlation but still that is not strong enough.
#
#
# #### In Fetal Heart Rate analysis, the important interaction is between fetal heart rate(LB) and Uterine Contractions(UC). Let us check if the change in UC has any effect on change in LB.(The dataset doesn't look like temporal data, but we are still checking if consecutive values are related in anyway)
#
# Note: We are using the scaled data to get a better view of the visualization

# %%
# Calculate change between consecutive observations
scaled_fetal['FHR_change'] = scaled_fetal['LB'].diff()  # Difference between consecutive values
scaled_fetal['UC_change'] = scaled_fetal['UC'].diff()

# Plot the changes in FHR and UC
plt.figure(figsize=(15, 10))
plt.plot(scaled_fetal.index, scaled_fetal['FHR_change'], label="Change in FHR", linestyle='-', color='blue')
plt.plot(scaled_fetal.index, scaled_fetal['UC_change'], label="Change in UC", linestyle='--', color='red')
plt.title('Change in FHR and UC Over Consecutive Measurements')
plt.xlabel('Index')
plt.ylabel('Change in Value')
plt.legend()
plt.show()

# %% [markdown]
# We can see whenever the UC is low, LB is low. There are some parts where when high UC conincides with high LB, but not always
#
# To view the change in FHR separately:

# %%
plt.figure(figsize=(10, 6))
plt.plot(scaled_fetal.index, scaled_fetal['FHR_change'], label="Change in FHR", linestyle='-', color='blue')

# %% [markdown]
# Let's see if LB can be divided into discrete ranges (e.g., bins), how Width varies across those ranges using a boxplot.

# %%
bins = [50, 100, 150, 200]  # Adjust bins based on your dataset
cleaner_fetal['LB_bins'] = pd.cut(cleaner_fetal['LB'], bins)

sns.boxplot(data=cleaner_fetal, x='LB_bins', y='Width')
plt.title('Width Distribution Across LB Ranges')
plt.xlabel('LB Bins')
plt.ylabel('Width')
plt.show()

# %% [markdown]
# ####  Barchart Analysis
# The spread (interquartile range) of Width is relatively consistent across bins, indicating that variability in Width does not dramatically change as LB increases.

# %%
# Calculate mean LB for each NSP category
mean_LB = cleaner_fetal.groupby('NSP_cat')['AC'].mean()

# Plot the bar chart
plt.figure(figsize=(8, 5))
mean_LB.plot(kind='bar', color=['#1f77b4', '#ff7f0e', '#2ca02c'], edgecolor='black')

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# <b>High Acceleration seem to be sign of normal fetus in our dataset</b>

# %%
# Calculate mean LB for each NSP category
mean_LB = cleaner_fetal.groupby('NSP_cat')['DS'].mean()

# Plot the bar chart
plt.figure(figsize=(8, 5))
mean_LB.plot(kind='bar', color=['#1f77b4', '#ff7f0e', '#2ca02c'], edgecolor='black')

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# <b>High DS looks like point of concern because the bar is tall for Class 2 and Class 3</b>

# %%
# List of variables to compare with FM
variables = ['LB', 'ASTV', 'MSTV', 'DL', 'DS', 'DP']

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 8))
axes = axes.flatten()

# Plot FM vs each variable
for i, var in enumerate(variables):
    sns.scatterplot(data=cleaner_fetal, x=var, y='FM', hue='NSP_cat', palette='Set2', ax=axes[i])
    axes[i].set_title(f'FM vs {var}')
    axes[i].set_xlabel(var)
    axes[i].set_ylabel('FM')

plt.tight_layout()
plt.show()

# %% [markdown]
# High DS (Short Decelerations) and FM (Fetal Movements) contributing to NSP = 3 (pathological) likely indicate fetal distress or overactivity due to stress.
#
# High DS: Frequent short decelerations suggest disrupted oxygen supply or response to stress, signaling potential distress.
#
# High FM: Excessive fetal movements may occur due to acute hypoxia (low oxygen), where the fetus reacts by moving more before becoming lethargic.

# %%
# List of features to plot
features = ['FM', 'LB', 'ASTV', 'MSTV', 'DL', 'DS', 'DP']

# Create subplots for each feature
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(18, 10))
axes = axes.flatten()

for i, feature in enumerate(features):
    sns.violinplot(data=cleaner_fetal, x='NSP_cat', y=feature, ax=axes[i], palette='Set2')
    axes[i].set_title(f'Violin Plot of {feature} by NSP')
    axes[i].set_xlabel('NSP Category')
    axes[i].set_ylabel(feature)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Observation:
#
# 1. LB: Class 3 has less variability, potentially indicating a more constrained baseline heart rate.
# 2.  FM:  Skews towards higher FM values, indicating increased FM is linked to pathological cases.
# 3. MSTV: Class 3, stands out as having a narrower range and lower variability, which could signify a pathological trend.
# 4. DL and DP: Almost no prolonged decelerations for Class 1 and 2.  High DP and DL are more frequent in pathological cases.

# %% [markdown]
# ### c.  Conclusion and Next steps
#
# - Our dataset were all continuous values, but we feature engineered two categorical values from them. There were categorized as:
#
# 1. Class 1 - Normal
# 2. Class 2- Suspicious
# 3. Class 3 - Pathological
#
# - There are many outliers in our dataset, we have decided to not to mess with the biological data yet. But, we have dealt with physiologically and scientifically impossible cases like negative values of acceleration, fetal movement, Uterine Contraction
# - After that, we can see the behaviour of Class 3(i.e, the pathological cases) were mostly different from Class 1 and Class 2.
# - Our features doesn't have much correlation between them. The highest correlation co efficient observed was 0.45
#
# Next steps:
# 1. Separate Analysis for oultier values to check for any unusal behavior.
# 2. Confirm the outlier values and its significance with an expert to get a better understanding of the data's behavior reason
# 3. As there is independence between the variables, this dataset is good for predictive modelling

# %% [markdown]
# # End of Analysis
